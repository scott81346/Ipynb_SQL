-- %% [markdown]
-- # [allenDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [allenDB]    Script Date: 5/24/2021 3:52:25 PM ******/
CREATE DATABASE [allenDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'allenDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\allenDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'allenDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\allenDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [allenDB] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [allenDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [allenDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [allenDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [allenDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [allenDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [allenDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [allenDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [allenDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [allenDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [allenDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [allenDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [allenDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [allenDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [allenDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [allenDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [allenDB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [allenDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [allenDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [allenDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [allenDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [allenDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [allenDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [allenDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [allenDB] SET RECOVERY FULL 
GO
ALTER DATABASE [allenDB] SET  MULTI_USER 
GO
ALTER DATABASE [allenDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [allenDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [allenDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [allenDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [allenDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [allenDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'allenDB', N'ON'
GO
ALTER DATABASE [allenDB] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[excise]

-- %%
USE [allenDB]
GO

-- %%
/****** Object:  Table [dbo].[excise]    Script Date: 5/24/2021 3:52:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[excise](
	[userid] [int] IDENTITY(1,1) NOT NULL,
	[useraccount] [nvarchar](50) NOT NULL,
	[userpassword] [nvarchar](50) NOT NULL,
	[usertelephone] [nvarchar](50) NOT NULL,
	[useremail] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK__excise__CBA1B257A3415B92] PRIMARY KEY CLUSTERED 
(
	[userid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[loginsystem]

-- %%
/****** Object:  Table [dbo].[loginsystem]    Script Date: 5/24/2021 3:52:25 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[loginsystem](
	[userid] [int] IDENTITY(1,1) NOT NULL,
	[username] [nvarchar](50) NOT NULL,
	[userpassword] [nvarchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[userid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[username] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [allenDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [allenDB] SET  READ_WRITE 
GO
